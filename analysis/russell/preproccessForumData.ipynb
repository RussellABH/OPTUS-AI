# %%
import pandas as pd
from datetime import datetime

# %%
print(f"Reading in data")
dfs = []
# pd.read_json("C:\\Users\\russe\\OneDrive\\Documents\\git\\Optus-data\\drugs-forum\\hydromorphone.json", orient='records')
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\buprenorphine.json", orient='records'), 'buprenorphine'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\codeine.json", orient='records'), 'codeine'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\heroin.json", orient='records'), 'heroin'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\hydrocodone.json", orient='records'), 'hydrocodone'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\hydromorphone.json", orient='records'), 'hydromorphone'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\methadone.json", orient='records'), 'methadone'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\morphine.json", orient='records'), 'morphine'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\opium-poppy.json", orient='records'), 'opium-poppy'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\oxycodone.json", orient='records'), 'oxycodone'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\oxymorphone.json", orient='records'), 'oxymorphone'))
dfs.append((pd.read_json("C:\\Users\\rharter2\\Documents\\Git\\optus_data\\drugs-forum\\tramadol.json", orient='records'), 'tramadol'))
# test = pd.DataFrame.from_dict(json.load(open("C:\\Users\\russe\\OneDrive\\Documents\\git\\Optus-data\\drugs-forum\\hydrocodone.json", encoding='utf-8')))

total = 0
for i in range(len(dfs)):
    print(f"File {i} shape: {dfs[i][0].shape} drug: {dfs[i][1]}")
    total += dfs[i][0].shape[0]
print(f"Total rows: {total}")
# Out:
# Reading in data
# File 0 shape: (9406, 10) drug: buprenorphine
# File 1 shape: (11135, 10) drug: codeine
# File 2 shape: (48437, 10) drug: heroin
# File 3 shape: (5215, 10) drug: hydrocodone
# File 4 shape: (2906, 10) drug: hydromorphone
# File 5 shape: (9030, 10) drug: methadone
# File 6 shape: (5132, 10) drug: morphine
# File 7 shape: (11630, 10) drug: opium-poppy
# File 8 shape: (15932, 10) drug: oxycodone
# File 9 shape: (1430, 10) drug: oxymorphone
# File 10 shape: (6797, 10) drug: tramadol
# Total rows: 127050

# %%
for tup in dfs:
    df = tup[0]
    drug = tup[1]
    df['join_date'] = df['join_date'].apply(lambda d: pd.to_datetime(datetime.strptime(d, '%b %d, %Y').timestamp(), unit='s'))
    df['date'] = df['date'].apply(lambda d: pd.to_datetime(datetime.strptime(str(d), '%Y-%m-%d %H:%M:%S').timestamp(), unit='s'))
    display(df.head())
    df.to_json(f"{drug}.json", orient='records')
# Out:
#             username                                       post_content  \
# 0            DanDone  Hi. I have a small codeine phosphate habit - I...
# 1      TheBigBadWolf  Hallo @Dan.\nTrying to get yourself straight a...
# 2            DanDone  Thank you. I do have some pregabalin so will c...
# 3      TheBigBadWolf  That's a good decision. \nAs I Had Said bupren...
# 4  Archangel Zadkiel  Thanks for the shout out @TheBigBadWolf long t...
#
#                rank rep_points messages           join_date  \
# 0            Newbie         10        8 2016-03-16 04:00:00
# 1       Gold Member     16,967    9,563 2010-04-11 04:00:00
# 2            Newbie         10        8 2016-03-16 04:00:00
# 3       Gold Member     16,967    9,563 2010-04-11 04:00:00
# 4  Palladium Member      3,445    1,936 2012-04-03 04:00:00
#
#                 country_of_origin                date  \
# 0                       from U.K. 2023-10-18 04:00:00
# 1                    from Germany 2023-10-18 04:00:00
# ...
