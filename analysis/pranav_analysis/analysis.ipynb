# %%
import pandas as pd
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

# initialize nlp
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
nlp.select_pipes(disable=['tok2vec','tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner'])

json_files = ['buprenorphine.json', 'codeine.json', 'heroin.json', 'hydrocodone.json', 'hydromorphone.json', 
               'methadone.json', 'morphine.json', 'opium-poppy.json', 'oxycodone.json', 'oxymorphone.json', 'tramadol.json']

df = pd.DataFrame()
dfs = []
for file in json_files:
    dfs.append(pd.read_json(file))

df = pd.concat(dfs)

# remove commas from rep points values
df['rep_points'] = df['rep_points'].str.replace(',', '').astype(int)

df.head()
# Out:
# ['spacytextblob']
#             username                                       post_content  \
# 0            DanDone  Hi. I have a small codeine phosphate habit - I...
# 1      TheBigBadWolf  Hallo @Dan.\nTrying to get yourself straight a...
# 2            DanDone  Thank you. I do have some pregabalin so will c...
# 3      TheBigBadWolf  That's a good decision. \nAs I Had Said bupren...
# 4  Archangel Zadkiel  Thanks for the shout out @TheBigBadWolf long t...
#
#                rank  rep_points messages     join_date  \
# 0            Newbie          10        8  Mar 16, 2016
# 1       Gold Member       16967    9,563  Apr 11, 2010
# 2            Newbie          10        8  Mar 16, 2016
# 3       Gold Member       16967    9,563  Apr 11, 2010
# 4  Palladium Member        3445    1,936   Apr 3, 2012
#
#                 country_of_origin       date  \
# 0                       from U.K. 2023-10-18
# 1                    from Germany 2023-10-18
# 2                       from U.K. 2023-10-18
# 3                    from Germany 2023-10-18
# 4  44\ny/o\nfrom Cincinnati, Ohio 2023-10-19
#
#                                     post_title post_type
# 0  Buprenorphine patch for codeine withdrawals  Question
# 1  Buprenorphine patch for codeine withdrawals  Question
# 2  Buprenorphine patch for codeine withdrawals  Question
# 3  Buprenorphine patch for codeine withdrawals  Question
# 4  Buprenorphine patch for codeine withdrawals  Question

# %% [markdown]
# Check to see if users with different ranks tend to have different sentiment in the way they speak. Lower 25th percentile is from 0 to 10, 50th percentile is from 11 to 80, 75th percentile is from 81 to 848, max is 18340

# %%
# percentile25 = df[(df['rep_points'] >= 0) & (df['rep_points'] <= 10)]

# Testing NLP
text = 'I think we should not do that. It is not a good idea in my opinion'
doc = nlp(text)
doc._.blob.sentiment

percentile_25 = df[(df['rep_points'] >= 0) & (df['rep_points'] <= 10)]['post_content'].str.apply(lambda text: nlp(text)._.blob.sentiment)
percentile_25.describe()

#percentile_50 = df[(df['rep_points'] > 10) & (df['rep_points'] <= 80)]['post_content'].apply(lambda text: nlp(text)._.blob.sentiment)
#percentile_50.describe()

#percentile_75 = df[(df['rep_points'] > 80) & (df['rep_points'] <= 848)]['post_content'].apply(lambda text: nlp(text)._.blob.sentiment)
#percentile_75.describe()

#percentile_100 = df[(df['rep_points'] > 848)]['post_content'].str.astype(str).apply(lambda text: nlp(text)._.blob.sentiment)
#percentile_100.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Pranav\OneDrive - Rensselaer Polytechnic Institute\Desktop\code\OPTUS-AI\analysis\pranav_analysis\analysis.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> doc = nlp(text)
#       <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> doc._.blob.sentiment
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> percentile_25 = df[(df['rep_points'] >= 0) & (df['rep_points'] <= 10)]['post_content'].str.apply(lambda text: nlp(text)._.blob.sentiment)
#       <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> percentile_25.describe()
#      <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> #percentile_50 = df[(df['rep_points'] > 10) & (df['rep_points'] <= 80)]['post_content'].apply(lambda text: nlp(text)._.blob.sentiment)
#      <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> #percentile_50.describe()
#      <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> #percentile_100 = df[(df['rep_points'] > 848)]['post_content'].str.astype(str).apply(lambda text: nlp(text)._.blob.sentiment)
#      <a href='vscode-notebook-cell:/c%3A/Users/Pranav/OneDrive%20-%20Rensselaer%20Polytechnic%20Institute/Desktop/code/OPTUS-AI/analysis/pranav_analysis/analysis.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> #percentile_100.describe()
#
# AttributeError: 'StringMethods' object has no attribute 'apply'
